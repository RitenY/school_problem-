# %%
import pandas as pd
df1 = pd.read_csv('data_by_pref_2021.csv')
df1.head()
# Out:
#   Unnamed: 0  Futoko  Gaku_elm  Gaku_jun  Seikatsu_jun  Tairyoku_elm  \
# 0   Hokkaido    5.99      65.0      60.5           5.1         51.80
# 1     Aomori    4.71      70.0      61.0           5.1         52.11
# 2      Iwate    3.99      66.5      60.0           5.6         53.64
# 3     Miyagi    6.08      65.5      60.0           5.4         52.15
# 4      Akita    4.44      71.5      64.0           5.9         54.71
#
#    Tairyoku_jun  Kurashi  Kyoiku  Kosodate  Family_1  Family_2  Family_3  \
# 0         39.31       45       0        19        70        43        46
# 1         41.82       24       2        14        73        54        42
# 2         43.74       27       0        14        62        39        37
# 3         41.41       38       3         9        72        46        51
# 4         44.00       23      16        14        64        34        38
#
#    Kyoikuhi  Family_4
# 0        16        28
# 1        14        24
# 2        18        25
# ...

# %%
for i in df1.columns:
    if i == 'Futoko':
        continue
    df1.plot(kind = 'scatter', x = i, y = 'Futoko')
