# %%
import pandas as pd
df1 = pd.read_csv('data_by_pref_2022.csv')
df1.head()
# Out:
#   Unnamed: 0  Futoko  Gaku_elm  Gaku_jun  Seikatsu_elm  Seikatsu_jun  \
# 0   Hokkaido    5.99      62.7      55.7           4.9           4.7
# 1     Aomori    4.71      65.7      56.7           5.3           5.2
# 2      Iwate    3.99      64.0      55.7           5.7           5.5
# 3     Miyagi    6.08      61.7      56.0           5.0           5.2
# 4      Akita    4.44      69.3      59.7           6.0           6.1
#
#    Tairyoku_elm  Tairyoku_jun  Kurashi  Kyoiku  Kosodate  Family_1  Family_2  \
# 0         51.74         38.97       32       0         7        66        32
# 1         52.08         41.44       22       0         7        66        44
# 2         52.83         43.46       32       3         7        62        34
# 3         51.44         41.13       42       2         9        67        45
# 4         54.31         43.40       19      17        10        57        33
#
#    Family_3  Kyoikuhi  Family_4
# 0        36        12        34
# ...

# %%
for i in df1.columns:
    if i == 'Futoko':
        continue
    df1.plot(kind = 'scatter', x = i, y = 'Futoko')
