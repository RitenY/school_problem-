# %%
import pandas as pd
df1 = pd.read_csv('data_by_pref_2020.csv')
df1.head()
# Out:
#   Unnamed: 0  Futoko  Kurashi  Kyoiku  Kosodate  Family_1  Family_2  Family_3  \
# 0   Hokkaido    5.07       45       3         9        55        39        27
# 1     Aomori    3.74       25       1        12        63        35        31
# 2      Iwate    3.34       29       0         9        64        33        28
# 3     Miyagi    4.65       45       1         8        70        36        37
# 4      Akita    3.53       25      20        17        56        30        32
#
#    Kyoikuhi  Family_4
# 0        14        34
# 1        12        34
# 2         8        33
# 3        15        33
# 4        11        32

# %%
for i in df1.columns:
    if i == 'Futoko':
        continue
    df1.plot(kind = 'scatter', x = i, y = 'Futoko')
