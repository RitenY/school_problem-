# %%
import pandas as pd
df1 = pd.read_csv('data_by_pref_2019.csv')

# %%
df1.head()
# Out:
#   Unnamed: 0  Futoko  Gaku_elm  Gaku_jun  Seikatsu_elm  Seikatsu_jun  \
# 0   Hokkaido    4.53      63.5      61.3           4.9           5.0
# 1     Aomori    3.21      68.5      63.0           5.5           5.2
# 2      Iwate    3.09      66.5      60.7           5.6           5.4
# 3     Miyagi    5.15      63.5      61.7           5.2           5.2
# 4      Akita    3.19      72.0      66.7           5.9           6.0
#
#    Tairyoku_elm  Tairyoku_jun  Kurashi  Kyoiku  Kosodate  Family_1  Family_2  \
# 0         52.82         40.28       27       3        12        61        32
# 1         53.70         42.28       20       1        11        57        32
# 2         54.49         43.48       31       0        14        65        45
# 3         53.25         41.77       48       1         7        69        37
# 4         56.06         43.87       25      20        15        58        38
#
#    Family_3  Kyoikuhi  Family_4  Teacher
# 0        36        13        32     61.2
# ...

# %%
for i in df1.columns:
    if i == 'Futoko':
        continue
    df1.plot(kind = 'scatter', x = i, y = 'Futoko')
